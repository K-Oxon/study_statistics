# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.4.3'

# %%
import matplotlib.pyplot as plt
import numpy as np

N = 100
xmin = 0
xmax = 10

l = 10  # 指数分布のラムダ

x = np.linspace(xmin, xmax, N)
y = 1 / l * np.exp(-x / l)  # 指数分布

plt.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots()

N = 200
xmin = 0
xmax = 20
x = np.linspace(xmin, xmax, N)

l1 = 1  # 指数分布のラムダ
l5 = 5

y1 = 1 / l1 * np.exp(-x / l1)  # 指数分布
y5 = 1 / l5 * np.exp(-x / l5)  # 指数分布

ax.set_xlabel("x")  # x軸ラベル
ax.set_ylabel("y")  # y軸ラベル
ax.set_title("exponential distribution")  # グラフタイトル
# ax.set_aspect('equal') # スケールを揃える
ax.plot(x, y1, label="l = 1")
ax.plot(x, y5, label="l = 5")
ax.legend(loc=0)  # 凡例
fig.tight_layout()  # レイアウトの設定
# plt.savefig('hoge.png') # 画像の保存
plt.show()
